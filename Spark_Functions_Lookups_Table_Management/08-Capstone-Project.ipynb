# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # Capstone Project: Custom Transformations, Aggregating and Loading
#
# The goal of this project is to populate aggregate tables using Twitter data.  In the process, you write custom User Defined Functions (UDFs), aggregate daily most trafficked domains, join new records to a lookup table, and load to a target database.
#
# ## Audience
# * Primary Audience: Data Engineers
# * Additional Audiences: Data Scientists and Data Pipeline Engineers
#
# ## Prerequisites
# * Web browser: Chrome or Firefox
# * Lesson: <a href="$./03-User-Defined-Functions">User Defined Functions</a>
# * Lesson: <a href="$./05-Joins-and-Lookup-Tables">Joins and Lookup Tables</a>
# * Lesson: <a href="$./06-Database-Writes">Database Writes</a>
#
# ## Instructions
#
# The Capstone work for the previous course in this series (ETL: Part 1) defined a schema and created tables to populate a relational mode. In this capstone project you take the project further.
#
# In this project you ETL JSON Twitter data to build aggregate tables that monitor trending websites and hashtags and filter malicious users using historical data.  Use these four exercises to achieve this goal:<br><br>
#
# 1. **Parse tweeted URLs** using a custom UDF
# 2. **Compute aggregate statistics** of most tweeted websites and hashtags by day
# 3. **Join new data** to an existing dataset of malicious users
# 4. **Load records** into a target database

# %% [markdown]
# Run the following cell.

# %%
# %run "./Includes/Classroom-Setup"

# %% [markdown]
# ## Exercise 1: Parse Tweeted URLs
#
# Some tweets in the dataset contain links to other websites.  Import and explore the dataset using the provided schema.  Then, parse the domain name from these URLs using a custom UDF.

# %% [markdown]
# ### Step 1: Import and Explore
#
# The following is the schema created as part of the capstone project for ETL Part 1.
# Run the following cell and then use this schema to import one file of the Twitter data.

# %%
from pyspark.sql.types import StructField, StructType, ArrayType, StringType, IntegerType, LongType
from pyspark.sql.functions import col

fullTweetSchema = StructType([
  StructField("id", LongType(), True),
  StructField("user", StructType([
    StructField("id", LongType(), True),
    StructField("screen_name", StringType(), True),
    StructField("location", StringType(), True),
    StructField("friends_count", IntegerType(), True),
    StructField("followers_count", IntegerType(), True),
    StructField("description", StringType(), True)
  ]), True),
  StructField("entities", StructType([
    StructField("hashtags", ArrayType(
      StructType([
        StructField("text", StringType(), True)
      ]),
    ), True),
    StructField("urls", ArrayType(
      StructType([
        StructField("url", StringType(), True),
        StructField("expanded_url", StringType(), True),
        StructField("display_url", StringType(), True)
      ]),
    ), True)
  ]), True),
  StructField("lang", StringType(), True),
  StructField("text", StringType(), True),
  StructField("created_at", StringType(), True)
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Import one file of the JSON data located at `/mnt/training/twitter/firehose/2018/01/08/18/twitterstream-1-2018-01-08-18-48-00-bcf3d615-9c04-44ec-aac9-25f966490aa4` using the schema.  Be sure to do the following:<br><br>
#
# * Save the result to `tweetDF`
# * Apply the schema `fullTweetSchema`
# * Filter out null values from the `id` column

# %%
from pyspark.sql.functions import col
path = "/mnt/training/twitter/firehose/2018/01/08/18/twitterstream-1-2018-01-08-18-48-00-bcf3d615-9c04-44ec-aac9-25f966490aa4"
tweetDF = (spark.read
          .schema(fullTweetSchema)
          .json(path)
          .filter(col("id").isNotNull()))
display(tweetDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>user</th><th>entities</th><th>lang</th><th>text</th><th>created_at</th></tr></thead><tbody><tr><td>950438954272096257</td><td>List(371607576, smileifyou_love, null, 473, 160, •Psalm 34:18• Living life one day at a time ✌️)</td><td>List(List(), List())</td><td>en</td><td>RT @TheTinaVasquez: Quick facts for the know-nothings who will tweet me today: MS-13 began in Los Angeles. The U.S. helped fund El Salvador…</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954288914432</td><td>List(732417055, bw198e18, null, 1641, 1285, 【期間限定】今なら無料！！ ただ今話題沸騰中の「ダイエットできるアプリ」こと「ヤセサポ」！！ 今だけ無料でダウンロードできます！この機会にぜひ！お試しあれ★ダウンロード⇒http://bit.ly/MxDjjc)</td><td>List(List(List(diet)), List())</td><td>ja</td><td>【太ももを引きしめるエクササイズ】足あげ～１．うつぶせに寝る。２．片方の足先を床から10センチ上にあげてキープ３．２の状態で足を振り上げる。※お腹が床から離れると× #diet</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954276450305</td><td>List(235927210, marlascigarette, null, 214, 223, △)</td><td>List(List(), List())</td><td>tr</td><td>Ben bir beni bulup icine girip saklanirsam kim beni bulur</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954280472576</td><td>List(1564880654, rebaab_1326, null, 45, 0, null)</td><td>List(List(List(صاروخ_سعودي_يرعب_ايران)), List(List(https://t.co/j0RgDwS36n, https://www.youtube.com/watch?v=b4iz9nZPzAA, youtube.com/watch?v=b4iz9n…)))</td><td>ar</td><td>تواصل قالوا عن قطر المتحدث باسم الجيش الصهيوني يشكر قناة الجزيرة https://t.co/j0RgDwS36n … #صاروخ_سعودي_يرعب_ايران</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954288889856</td><td>List(349070364, puskine, Kampala, Uganda, 5008, 4916, God first . Football fun . Talk so much . Reader. Year of FINANCIAL BREAK THROUGH . Still learning how to love
# kibitram@gmail.com.
# +256779646952)</td><td>List(List(), List())</td><td>en</td><td>*Before you argue about your dirty house someone didn't clean or sweep -*
# *Think of the people who are living in the streets.*</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954280669184</td><td>List(340482488, xNina_Beana, the land , 1130, 1646, Prince Carter ❤️ && Messiah Carter Miles ❤️)</td><td>List(List(), List())</td><td>en</td><td>RT @TippyLexx: Bruh you ever accidentally open a message and be like damn now I gotta reply 😂😂</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954276442113</td><td>List(4354072997, gbfranca22, cpx da congo🔞, 252, 632, mãe nunca te escutei, mas sempre te amarei❤)</td><td>List(List(), List())</td><td>pt</td><td>RT @MorraoTudo2: A liberdade é só questão de tempo, solta os faixa preta 🔐🔓⏳✌️</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954276478976</td><td>List(738897225061912576, squeeqi, null, 213, 160, We are two guys who have great knowledge in scripting. If you have 10k+ coins on CSGODouble we can help you triple that amount. Check out how in the link below)</td><td>List(List(), List())</td><td>en</td><td>I just want this all to be over</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954289033216</td><td>List(273646363, iiib53, null, 631, 427, null)</td><td>List(List(), List())</td><td>ar</td><td>RT @Arab_original: للاسف قطاع كان ممكن حل ولا اروع للبطاله لكن وزارة النقل قررت ان لا تنظم السوق بحجه السوق الحرة !! اي حريه والشركتين يسحق…</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954289033218</td><td>List(1541143441, nappo_what, 🇫🇮🇺🇦, 297, 925, null)</td><td>List(List(), List())</td><td>ru</td><td>RT @craneswordboi: блять мне так смешно от слова срождество</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954297303040</td><td>List(2937433261, zooeeen, null, 220, 3165, ✨🧚🏽‍♀️  (ﾉ◕ヮ◕)ﾉ*:･ﾟ)</td><td>List(List(List(Tea), List(GoldenGlobes)), List())</td><td>en</td><td>RT @oscahhhhh: THE MOMENT NATALIE PORTMAN SNAPPED #Tea #GoldenGlobes https://t.co/EJbw5q5T2j</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954297274368</td><td>List(3318213908, vickydxblas, followed by Shawn Mendes , 403, 1023, R.I.P. to my youth / 16 / I am not as fine as I seem / tøp / house Targaryen 🐲 / be a maverick / marvel / LOGANG4LIFE)</td><td>List(List(), List())</td><td>en</td><td>RT @troyesivan: ❤ 'MY MY MY!' OFFICIAL ARTWORK ❤ JANUARY 10, 9PM PST ❤ https://t.co/dBNJZTi7AE</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954272215041</td><td>List(2296919349, mirkoasuarezm, null, 23, 44, null)</td><td>List(List(), List())</td><td>es</td><td>@Capital967 @ADiezGol @diegoreba @cokigonzales Uy carnecita pa....</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954297208832</td><td>List(766017625495314433, HctorNol3, Durango, México, 335, 29, Hay historias inolvidables pero hay otras que ni loco quisieras recordar ⚔)</td><td>List(List(), List())</td><td>en</td><td>RT @KitoriJP: The evolution of Knuckles. https://t.co/hcBXyoqZFy</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954297249792</td><td>List(948483890468958208, Astel_SWG, 오늘도 부디 무사히 다녀오세요., 27, 27, [ 23 | 남 | 달의 호각 | 펜 달린 수첩, 장작 11, 고무덩어리, 아스텔 1호 2, 후타마 3] 1월 9일 3시 75/100 | * 운영으로.. 답멘이 늦어서 죄송합니다 8ㅆ8))</td><td>List(List(), List())</td><td>ko</td><td>@KAYA_SWG @VNT_SWG @lento_SWG 졸려서 그런겁니다, 카야. 얼른 주무세요.</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954276409346</td><td>List(2395396997, preetinhaeu, null, 99, 313, null)</td><td>List(List(), List())</td><td>pt</td><td>to com muita saudade do gustavo cara, nossa
# não consigo ficar longe dessa criança</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954301472768</td><td>List(2791365483, hamtorihyodorie, 태국, 236, 88, null)</td><td>List(List(), List())</td><td>ko</td><td>RT @bbbbkim: 냄비받침 (편백) .. https://t.co/bTMQIjjTnL</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954284797958</td><td>List(3243825293, kersplats, rio de janeiro, 762, 690, artista e rosquinha • ilustrações aqui e no meu instagram @kersplarts (o˘◡˘o))</td><td>List(List(), List(List(https://t.co/B5Zgkoy4TL, https://twitter.com/i/web/status/950438954284797958, twitter.com/i/web/status/9…)))</td><td>en</td><td>you make me un poco loco, un poquititito loco
# the way you keep me guessing, I'm nodding and i'm yesing
# I'll count i… https://t.co/B5Zgkoy4TL</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954301579265</td><td>List(948709436570382336, felixcantillo, null, 259, 6, Perseverancia.)</td><td>List(List(), List())</td><td>es</td><td>@zonacero Jummm. Me huele a humo</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954288984064</td><td>List(893053271245549568, mangootaktk, null, 2086, 131, null)</td><td>List(List(), List())</td><td>und</td><td>RT @DatAzzPhatAF: https://t.co/Ccg78SZLNx</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954297450497</td><td>List(941196347486752769, figendinceralr1, null, 33, 13, null)</td><td>List(List(), List())</td><td>tr</td><td>MUSTAFA KEMAL ATATÜRKİYE ...</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954305716226</td><td>List(1438498315, HFC_56_k, null, 305, 250, هلالي ... الزعيم ...ملكي...فلكي ...بطل السداسيه ....مدريدي 1️⃣2️⃣)</td><td>List(List(List(الهلال_الاتفاق)), List())</td><td>ar</td><td>لازم يقتنع ان العرضيات ما تنفع  #الهلال_الاتفاق</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954276356098</td><td>List(300784082, laurenpedia, Motonui, 277, 983, repeat after me: i can do this)</td><td>List(List(), List())</td><td>pt</td><td>RT @iloveputarias: ter intimidade pra falar sobre qualquer assunto com alguém é bom pra crlh</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>950438954310033410</td><td>List(913092712282431491, Mem_Alive, Dallas, TX, 375, 208, Memories Alive: a mo

# %%
# TEST - Run this cell to test your solution
dbTest("ET2-P-08-01-01", 1491, tweetDF.count())
dbTest("ET2-P-08-01-02", True, "text" in tweetDF.columns and "id" in tweetDF.columns)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# -sandbox
# ### Step 2: Write a UDF to Parse URLs
#
# The Python regular expression library `re` allows you to define a set of rules of a string you want to match. In this case, parse just the domain name in the string for the URL of a link in a Tweet. Take a look at the following example:
#
# ```
# import re
#
# URL = "https://www.databricks.com/"
# pattern = re.compile(r"https?://(www\.)?([^/#?]+).*$")
# match = pattern.search(URL)
# print("The string {} matched {}".format(URL, match.group(2)))
# ```
#
# This code prints `The string https://www.databricks.com/ matched spark.apache.org`. **Wrap this code into a function named `getDomain` that takes a parameter `URL` and returns the matched string.**
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> <a href="https://docs.python.org/3/howto/regex.html" target="_blank">You can find more on the `re` library here.</a>

# %%
import re
def getDomain(URL):
  pattern = re.compile(r"https?://(www\.)?([^/#?]+).*$")
  match = pattern.search(URL)
  return match.group(2)
URL = "https://www.databricks.com/"
print("The string {} matched {}".format(URL, getDomain(URL)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The string https://www.databricks.com/ matched databricks.com
# </div>

# %%
# TEST - Run this cell to test your solution
dbTest("ET2-P-08-02-01", "databricks.com",  getDomain("https://www.databricks.com/"))

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ### Step 3: Test and Register the UDF
#
# Now that the function works with a single URL, confirm that it works on different URL formats.

# %% [markdown]
# Run the following cell to test your function further.

# %%
urls = [
  "https://www.databricks.com/",
  "https://databricks.com/",
  "https://databricks.com/training-overview/training-self-paced",
  "http://www.databricks.com/",
  "http://databricks.com/",
  "http://databricks.com/training-overview/training-self-paced",
  "http://www.apache.org/",
  "http://spark.apache.org/docs/latest/"
]

for url in urls:
  print(getDomain(url))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">databricks.com
# databricks.com
# databricks.com
# databricks.com
# databricks.com
# databricks.com
# apache.org
# spark.apache.org
# </div>

# %% [markdown]
# Register the UDF as `getDomainUDF`.

# %%
from pyspark.sql.types import StructField, StructType, ArrayType, StringType, IntegerType, LongType
getDomainUDF = spark.udf.register("getDomainUDF",getDomain,StringType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution
dbTest("ET2-P-08-03-01", True, bool(getDomainUDF))

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ### Step 4: Apply the UDF
#
# Create a dataframe called `urlDF` that has three columns:<br><br>
#
# 1. `URL`: The URL's from `tweetDF` (located in `entities.urls.expanded_url`)
# 2. `parsedURL`: The UDF applied to the column `URL`
# 3. `created_at`
#
# There can be zero, one, or many URLs in any tweet.  For this step, use the `explode` function, which takes an array like URLs and returns one row for each value in the array.
# <a href="http://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=explode#pyspark.sql.functions.explode" target="_blank">See the documents here for details.</a>

# %%
from pyspark.sql.functions import explode
urlDF = tweetDF.select(explode("entities.urls.expanded_url").alias("URL"),getDomainUDF("URL").alias("parsedURL"),"created_at")
display(urlDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>URL</th><th>parsedURL</th><th>created_at</th></tr></thead><tbody><tr><td>https://www.youtube.com/watch?v=b4iz9nZPzAA</td><td>youtube.com</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>https://twitter.com/i/web/status/950438954284797958</td><td>twitter.com</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>http://bit.ly/OYlKII</td><td>bit.ly</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>https://goo.gl/fb/atjACB</td><td>goo.gl</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>https://www.instagram.com/p/BdsvNFABXNL/</td><td>instagram.com</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>https://twitter.com/i/web/status/950438954301644800</td><td>twitter.com</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>http://alathkar.org</td><td>alathkar.org</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>https://open.spotify.com/album/60eldei5NAr7QjPGr3Ei1B</td><td>open.spotify.com</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>https://twitter.com/i/web/status/950438954301616131</td><td>twitter.com</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>https://twitter.com/frann_frann_/status/949080362218606592</td><td>twitter.com</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>https://twitter.com/thisisinsider/status/950398060072460289</td><td>twitter.com</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>http://goo.gl/TU8gBa</td><td>goo.gl</td><td>Mon Jan 08 18:47:59 +0000 2018</td></tr><tr><td>https://twitter.com/i/web/status/950438958470545408</td><td>twitter.com</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>https://du3a.org/</td><td>du3a.org</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>http://whounfollowedme.org</td><td>whounfollowedme.org</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>https://goo.gl/RgE1Vz</td><td>goo.gl</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>http://du3a.org</td><td>du3a.org</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>https://twitter.com/i/web/status/950438958487494658</td><td>twitter.com</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>https://twitter.com/i/web/status/950438958487494657</td><td>twitter.com</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>https://twitter.com/edward_mwale/status/950221934603767808</td><td>twitter.com</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>http://a.pgtb.me/l0JjmW/ncJG5</td><td>a.pgtb.me</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>https://vine.co/v/O7qbhaKnLIO</td><td>vine.co</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>https://twitter.com/i/web/status/950438958504267777</td><td>twitter.com</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>http://ww.elbernabeu.com/Q9P5tC</td><td>ww.elbernabeu.com</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>http://pianoforalltips.blogspot.com</td><td>pianoforalltips.blogspot.com</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>http://www.fashionglamtrends.com/now-anyone-can-learn-piano-or-keyboard/</td><td>fashionglamtrends.com</td><td>Mon Jan 08 18:48:00 +0000 2018</td></tr><tr><td>http://tinyurl.com/ycc6je3d</td><td>tinyurl.com</td><td>Mon Jan 08 18:48:01 +0000 2018</td></tr><tr><td>https://twitter.com/i/web/status/950438962677604352</td><td>twitter.com</td><td>Mon Jan 08 18:48:01 +0000 2018</td></tr><tr><td>http://du3a.org/</td><td>du3a.org</td><td>Mon Jan 08 18:48:01 +0000 2018</td></tr><tr><td>http://du3a.org</td><td>du3a.org</td><td>Mon Jan 08 18:48:01 +0000 2018</td></tr><tr><td>https://twitter.com/shellywelly53/status/950076119457435648</td><td>twitter.com</td><td>Mon Jan 08 18:48:01 +0000 2018</td></tr><tr><td>https://wp.me/p2C6hV-LW6</td><td>wp.me</td><td>Mon Jan 08 18:48:01 +0000 2018</td></tr><tr><td>https://wp.me/p2C6hV-LW6</td><td>wp.me</td><td>Mon Jan 08 18:48:01 +0000 2018</td></tr><tr><td>https://twitter.com/mariaf ...

# %%
# TEST - Run this cell to test your solution
cols = urlDF.columns
sample = urlDF.first()

dbTest("ET2-P-08-04-01", True, "URL" in cols and "parsedURL" in cols and "created_at" in cols)
dbTest("ET2-P-08-04-02", "https://www.youtube.com/watch?v=b4iz9nZPzAA", sample["URL"])
dbTest("ET2-P-08-04-03", "Mon Jan 08 18:47:59 +0000 2018", sample["created_at"])
dbTest("ET2-P-08-04-04", "youtube.com", sample["parsedURL"])

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ## Exercise 2: Compute Aggregate Statistics
#
# Calculate top trending 10 URLs by hour.

# %% [markdown]
# ### Step 1: Parse the Timestamp
#
# Create a DataFrame `urlWithTimestampDF` that includes the following columns:<br><br>
#
# * `URL`
# * `parsedURL`
# * `timestamp`
# * `hour`
#
# Import `unix_timestamp` and `hour` from the `functions` module and `TimestampType` from the types `module`. To parse the `create_at` field, use `unix_timestamp` with the format `EEE MMM dd HH:mm:ss ZZZZZ yyyy`.

# %%
from pyspark.sql.functions import unix_timestamp,hour
from pyspark.sql.types import TimestampType
timestampFormat = "EEE MMM dd HH:mm:ss ZZZZZ yyyy"
urlWithTimestampDF1 = urlDF.select(
"URL","parsedURL",unix_timestamp("created_at","EEE MMM dd HH:mm:ss ZZZZZ yyyy").astype(TimestampType()).alias("timestamp")
)
urlWithTimestampDF=urlWithTimestampDF1.select("URL","parsedURL","timestamp",hour("timestamp").alias("hour"))
display(urlWithTimestampDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>URL</th><th>parsedURL</th><th>timestamp</th><th>hour</th></tr></thead><tbody><tr><td>https://www.youtube.com/watch?v=b4iz9nZPzAA</td><td>youtube.com</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/i/web/status/950438954284797958</td><td>twitter.com</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>http://bit.ly/OYlKII</td><td>bit.ly</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>https://goo.gl/fb/atjACB</td><td>goo.gl</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>https://www.instagram.com/p/BdsvNFABXNL/</td><td>instagram.com</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/i/web/status/950438954301644800</td><td>twitter.com</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>http://alathkar.org</td><td>alathkar.org</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>https://open.spotify.com/album/60eldei5NAr7QjPGr3Ei1B</td><td>open.spotify.com</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/i/web/status/950438954301616131</td><td>twitter.com</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/frann_frann_/status/949080362218606592</td><td>twitter.com</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/thisisinsider/status/950398060072460289</td><td>twitter.com</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>http://goo.gl/TU8gBa</td><td>goo.gl</td><td>2018-01-08T18:47:59.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/i/web/status/950438958470545408</td><td>twitter.com</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>https://du3a.org/</td><td>du3a.org</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>http://whounfollowedme.org</td><td>whounfollowedme.org</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>https://goo.gl/RgE1Vz</td><td>goo.gl</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>http://du3a.org</td><td>du3a.org</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/i/web/status/950438958487494658</td><td>twitter.com</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/i/web/status/950438958487494657</td><td>twitter.com</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/edward_mwale/status/950221934603767808</td><td>twitter.com</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>http://a.pgtb.me/l0JjmW/ncJG5</td><td>a.pgtb.me</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>https://vine.co/v/O7qbhaKnLIO</td><td>vine.co</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/i/web/status/950438958504267777</td><td>twitter.com</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>http://ww.elbernabeu.com/Q9P5tC</td><td>ww.elbernabeu.com</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>http://pianoforalltips.blogspot.com</td><td>pianoforalltips.blogspot.com</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>http://www.fashionglamtrends.com/now-anyone-can-learn-piano-or-keyboard/</td><td>fashionglamtrends.com</td><td>2018-01-08T18:48:00.000+0000</td><td>18</td></tr><tr><td>http://tinyurl.com/ycc6je3d</td><td>tinyurl.com</td><td>2018-01-08T18:48:01.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/i/web/status/950438962677604352</td><td>twitter.com</td><td>2018-01-08T18:48:01.000+0000</td><td>18</td></tr><tr><td>http://du3a.org/</td><td>du3a.org</td><td>2018-01-08T18:48:01.000+0000</td><td>18</td></tr><tr><td>http://du3a.org</td><td>du3a.org</td><td>2018-01-08T18:48:01.000+0000</td><td>18</td></tr><tr><td>https://twitter.com/shellywelly53/status/950076119457435648</td><td>tw ...

# %%
# TEST - Run this cell to test your solution
cols = urlWithTimestampDF.columns
sample = urlWithTimestampDF.first()

dbTest("ET2-P-08-05-01", True, "URL" in cols and "parsedURL" in cols and "timestamp" in cols and "hour" in cols)
dbTest("ET2-P-08-05-02", 18, sample["hour"])

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ### Step 2: Calculate Trending URLs
#
# Create a DataFrame `urlTrendsDF` that looks at the top 10 hourly counts of domain names and includes the following columns:<br><br>
#
# * `hour`
# * `parsedURL`
# * `count`
#
# The result should sort `hour` in ascending order and `count` in descending order.

# %%
from pyspark.sql.functions import count,col, desc
urlTrendsDF = (urlWithTimestampDF
               .select("hour","parsedURL")
               .groupBy("parsedURL","hour")
               .count().alias("count")
               .orderBy(desc("count"))
               .limit(10)
              )
display(urlTrendsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>parsedURL</th><th>hour</th><th>count</th></tr></thead><tbody><tr><td>twitter.com</td><td>18</td><td>159</td></tr><tr><td>bit.ly</td><td>18</td><td>25</td></tr><tr><td>fb.me</td><td>18</td><td>17</td></tr><tr><td>youtu.be</td><td>18</td><td>16</td></tr><tr><td>du3a.org</td><td>18</td><td>15</td></tr><tr><td>goo.gl</td><td>18</td><td>12</td></tr><tr><td>instagram.com</td><td>18</td><td>10</td></tr><tr><td>curiouscat.me</td><td>18</td><td>6</td></tr><tr><td>dlvr.it</td><td>18</td><td>4</td></tr><tr><td>youtube.com</td><td>18</td><td>3</td></tr></tbody></table></div>

# %%
# TEST - Run this cell to test your solution
cols = urlTrendsDF.columns
sample = urlTrendsDF.first()

dbTest("ET2-P-08-06-01", True, "hour" in cols and "parsedURL" in cols and "count" in cols)
dbTest("ET2-P-08-06-02", 18, sample["hour"])
dbTest("ET2-P-08-06-03", "twitter.com", sample["parsedURL"])
dbTest("ET2-P-08-06-04", 159, sample["count"])

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ## Exercise 3: Join New Data
#
# Filter out bad users.

# %% [markdown]
# ### Step 1: Import Table of Bad Actors
#
# Create the DataFrame `badActorsDF`, a list of bad actors that sits in `/mnt/training/twitter/supplemental/badactors.parquet`.

# %%
badActorsDF = (spark.read
              .parquet("/mnt/training/twitter/supplemental/badactors.parquet")
              )
display(badActorsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userID</th><th>screenName</th></tr></thead><tbody><tr><td>4875602384</td><td>cris_silvag1</td></tr><tr><td>2641769580</td><td>therebel1789</td></tr><tr><td>932599236516024320</td><td>HiLeonyedek88</td></tr><tr><td>573733345</td><td>KristenSel</td></tr><tr><td>1458487634</td><td>ImPostMaIone</td></tr><tr><td>541253458</td><td>Santa_Palabra</td></tr><tr><td>1942419721</td><td>fidgazi</td></tr><tr><td>950292653207425024</td><td>marylinbrown272</td></tr><tr><td>2333871434</td><td>LryManon</td></tr><tr><td>3519647781</td><td>FeatuuedPromos</td></tr><tr><td>2287969007</td><td>Turguthuseyin45</td></tr><tr><td>76528887</td><td>CoteRubioS</td></tr><tr><td>873555938887651328</td><td>F_poke_ATs</td></tr><tr><td>4839362237</td><td>Ahmed0_2016</td></tr><tr><td>923874480895774722</td><td>FortuneCli</td></tr><tr><td>17441094</td><td>Michellpollino</td></tr><tr><td>703982228011917312</td><td>alyahyaalyamine</td></tr><tr><td>1267107800</td><td>mramorealskayaa</td></tr><tr><td>808049534118920193</td><td>G00dVibez0nly13</td></tr><tr><td>135745429</td><td>higeneko_999</td></tr><tr><td>235661089</td><td>Barl1954</td></tr><tr><td>949889119290908673</td><td>8JVD5HzhqdL9N15</td></tr><tr><td>941196347486752769</td><td>figendinceralr1</td></tr><tr><td>3008926868</td><td>joandgordonjoan</td></tr><tr><td>968610984</td><td>shwevs</td></tr><tr><td>2887055418</td><td>inmudaisukikun</td></tr><tr><td>2398163642</td><td>srmoisesguevara</td></tr><tr><td>1962660961</td><td>_ThaAnomaly</td></tr><tr><td>803935495399075840</td><td>Saraa79_</td></tr><tr><td>754702216221626368</td><td>Wonhoseoksz</td></tr><tr><td>864853471815663616</td><td>na39ra39</td></tr><tr><td>938517421429809153</td><td>kaarina_becker</td></tr><tr><td>87347666</td><td>victoria1039fm</td></tr><tr><td>4601931155</td><td>shirleynorquay</td></tr><tr><td>2757352306</td><td>mrslynchsclass</td></tr><tr><td>797720545</td><td>jannabananaaa_</td></tr><tr><td>4869837172</td><td>Native66636832</td></tr><tr><td>410571548</td><td>Madison_Alcine</td></tr><tr><td>915793053549461504</td><td>CommitDOLANS16</td></tr><tr><td>943118738416574464</td><td>kyoeuninurarea</td></tr><tr><td>517983692</td><td>raul___jimenez</td></tr><tr><td>700709279284658176</td><td>ElifnurENGN1</td></tr><tr><td>394034173</td><td>_Nefertari__</td></tr><tr><td>141529750</td><td>LauraCarrese</td></tr><tr><td>945782861105385472</td><td>TitanideRhea</td></tr><tr><td>805065198159757314</td><td>suetimothyuk</td></tr><tr><td>3381233957</td><td>mernamegahed</td></tr><tr><td>547600986</td><td>S_alharbi_1</td></tr><tr><td>118929355</td><td>ociotextual</td></tr><tr><td>730978055506690048</td><td>loveramit88</td></tr><tr><td>560400907</td><td>sunshyminie</td></tr><tr><td>178540348</td><td>Marceloigv</td></tr><tr><td>112641095</td><td>kisho4ever</td></tr><tr><td>3093622433</td><td>GalaxyB666</td></tr><tr><td>209780012</td><td>FalaRenata</td></tr><tr><td>758961747432648704</td><td>mewisepost</td></tr><tr><td>1521794970</td><td>Ravzamsin</td></tr><tr><td>884139816954331139</td><td>taehelion</td></tr><tr><td>280368714</td><td>jfieldsjr</td></tr><tr><td>4808507779</td><td>the__niiz</td></tr><tr><td>2904771746</td><td>ItiSushil</td></tr><tr><td>527844923</td><td>Skuadnews</td></tr><tr><td>895894126427725824</td><td>Guptahkji</td></tr><tr><td>742785093257793536</td><td>abeerkh96</td></tr><tr><td>3258036915</td><td>burcu2811</td></tr><tr><td>437641011</td><td>NekroBun</td></tr><tr><td>2858060254</td><td>umiboomi</td></tr><tr><td>946079193552637955</td><td>mrt_akoz</td></tr><tr><td>727498819399745536</td><td>espoirTr</td></tr><tr><td>891262942569787393</td><td>m__Mlkh</td></tr><tr><td>273646363</td><td>iiib53</td></tr><tr><td>762452665745846272</td><td>iiw_59</td></tr></tbody></table></div>

# %%
# TEST - Run this cell to test your solution
cols = badActorsDF.columns
sample = badActorsDF.first()

dbTest("ET2-P-08-07-01", True, "userID" in cols and "screenName" in cols)
dbTest("ET2-P-08-07-02", 4875602384, sample["userID"])
dbTest("ET2-P-08-07-03", "cris_silvag1", sample["screenName"])

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ### Step 2: Add a Column for Bad Actors
#
# Add a new column to `tweetDF` called `maliciousAcct` with `true` if the user is in `badActorsDF`.  Save the results to `tweetWithMaliciousDF`.  Remember to do a left join of the malicious accounts on `tweetDF`.

# %%
from pyspark.sql import functions as F

tweetDF2 = tweetDF.join(badActorsDF,tweetDF.user.id==badActorsDF.userID,"left_outer")
tweetWithMaliciousDF=tweetDF2.select("*",F.when(tweetDF2.screenName.isNull(),False).otherwise(True).alias("maliciousAcct"))


display(tweetWithMaliciousDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>user</th><th>entities</th><th>lang</th><th>text</th><th>created_at</th><th>userID</th><th>screenName</th><th>maliciousAcct</th></tr></thead><tbody><tr><td>950438954272096257</td><td>List(371607576, smileifyou_love, null, 473, 160, •Psalm 34:18• Living life one day at a time ✌️)</td><td>List(List(), List())</td><td>en</td><td>RT @TheTinaVasquez: Quick facts for the know-nothings who will tweet me today: MS-13 began in Los Angeles. The U.S. helped fund El Salvador…</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954288914432</td><td>List(732417055, bw198e18, null, 1641, 1285, 【期間限定】今なら無料！！ ただ今話題沸騰中の「ダイエットできるアプリ」こと「ヤセサポ」！！ 今だけ無料でダウンロードできます！この機会にぜひ！お試しあれ★ダウンロード⇒http://bit.ly/MxDjjc)</td><td>List(List(List(diet)), List())</td><td>ja</td><td>【太ももを引きしめるエクササイズ】足あげ～１．うつぶせに寝る。２．片方の足先を床から10センチ上にあげてキープ３．２の状態で足を振り上げる。※お腹が床から離れると× #diet</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954276450305</td><td>List(235927210, marlascigarette, null, 214, 223, △)</td><td>List(List(), List())</td><td>tr</td><td>Ben bir beni bulup icine girip saklanirsam kim beni bulur</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954280472576</td><td>List(1564880654, rebaab_1326, null, 45, 0, null)</td><td>List(List(List(صاروخ_سعودي_يرعب_ايران)), List(List(https://t.co/j0RgDwS36n, https://www.youtube.com/watch?v=b4iz9nZPzAA, youtube.com/watch?v=b4iz9n…)))</td><td>ar</td><td>تواصل قالوا عن قطر المتحدث باسم الجيش الصهيوني يشكر قناة الجزيرة https://t.co/j0RgDwS36n … #صاروخ_سعودي_يرعب_ايران</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954288889856</td><td>List(349070364, puskine, Kampala, Uganda, 5008, 4916, God first . Football fun . Talk so much . Reader. Year of FINANCIAL BREAK THROUGH . Still learning how to love
# kibitram@gmail.com.
# +256779646952)</td><td>List(List(), List())</td><td>en</td><td>*Before you argue about your dirty house someone didn't clean or sweep -*
# *Think of the people who are living in the streets.*</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954280669184</td><td>List(340482488, xNina_Beana, the land , 1130, 1646, Prince Carter ❤️ && Messiah Carter Miles ❤️)</td><td>List(List(), List())</td><td>en</td><td>RT @TippyLexx: Bruh you ever accidentally open a message and be like damn now I gotta reply 😂😂</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954276442113</td><td>List(4354072997, gbfranca22, cpx da congo🔞, 252, 632, mãe nunca te escutei, mas sempre te amarei❤)</td><td>List(List(), List())</td><td>pt</td><td>RT @MorraoTudo2: A liberdade é só questão de tempo, solta os faixa preta 🔐🔓⏳✌️</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954276478976</td><td>List(738897225061912576, squeeqi, null, 213, 160, We are two guys who have great knowledge in scripting. If you have 10k+ coins on CSGODouble we can help you triple that amount. Check out how in the link below)</td><td>List(List(), List())</td><td>en</td><td>I just want this all to be over</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954289033216</td><td>List(273646363, iiib53, null, 631, 427, null)</td><td>List(List(), List())</td><td>ar</td><td>RT @Arab_original: للاسف قطاع كان ممكن حل ولا اروع للبطاله لكن وزارة النقل قررت ان لا تنظم السوق بحجه السوق الحرة !! اي حريه والشركتين يسحق…</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>273646363</td><td>iiib53</td><td>true</td></tr><tr><td>950438954289033218</td><td>List(1541143441, nappo_what, 🇫🇮🇺🇦, 297, 925, null)</td><td>List(List(), List())</td><td>ru</td><td>RT @craneswordboi: блять мне так смешно от слова срождество</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954297303040</td><td>List(2937433261, zooeeen, null, 220, 3165, ✨🧚🏽‍♀️  (ﾉ◕ヮ◕)ﾉ*:･ﾟ)</td><td>List(List(List(Tea), List(GoldenGlobes)), List())</td><td>en</td><td>RT @oscahhhhh: THE MOMENT NATALIE PORTMAN SNAPPED #Tea #GoldenGlobes https://t.co/EJbw5q5T2j</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954297274368</td><td>List(3318213908, vickydxblas, followed by Shawn Mendes , 403, 1023, R.I.P. to my youth / 16 / I am not as fine as I seem / tøp / house Targaryen 🐲 / be a maverick / marvel / LOGANG4LIFE)</td><td>List(List(), List())</td><td>en</td><td>RT @troyesivan: ❤ 'MY MY MY!' OFFICIAL ARTWORK ❤ JANUARY 10, 9PM PST ❤ https://t.co/dBNJZTi7AE</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954272215041</td><td>List(2296919349, mirkoasuarezm, null, 23, 44, null)</td><td>List(List(), List())</td><td>es</td><td>@Capital967 @ADiezGol @diegoreba @cokigonzales Uy carnecita pa....</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954297208832</td><td>List(766017625495314433, HctorNol3, Durango, México, 335, 29, Hay historias inolvidables pero hay otras que ni loco quisieras recordar ⚔)</td><td>List(List(), List())</td><td>en</td><td>RT @KitoriJP: The evolution of Knuckles. https://t.co/hcBXyoqZFy</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954297249792</td><td>List(948483890468958208, Astel_SWG, 오늘도 부디 무사히 다녀오세요., 27, 27, [ 23 | 남 | 달의 호각 | 펜 달린 수첩, 장작 11, 고무덩어리, 아스텔 1호 2, 후타마 3] 1월 9일 3시 75/100 | * 운영으로.. 답멘이 늦어서 죄송합니다 8ㅆ8))</td><td>List(List(), List())</td><td>ko</td><td>@KAYA_SWG @VNT_SWG @lento_SWG 졸려서 그런겁니다, 카야. 얼른 주무세요.</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954276409346</td><td>List(2395396997, preetinhaeu, null, 99, 313, null)</td><td>List(List(), List())</td><td>pt</td><td>to com muita saudade do gustavo cara, nossa
# não consigo ficar longe dessa criança</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954301472768</td><td>List(2791365483, hamtorihyodorie, 태국, 236, 88, null)</td><td>List(List(), List())</td><td>ko</td><td>RT @bbbbkim: 냄비받침 (편백) .. https://t.co/bTMQIjjTnL</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954284797958</td><td>List(3243825293, kersplats, rio de janeiro, 762, 690, artista e rosquinha • ilustrações aqui e no meu instagram @kersplarts (o˘◡˘o))</td><td>List(List(), List(List(https://t.co/B5Zgkoy4TL, https://twitter.com/i/web/status/950438954284797958, twitter.com/i/web/status/9…)))</td><td>en</td><td>you make me un poco loco, un poquititito loco
# the way you keep me guessing, I'm nodding and i'm yesing
# I'll count i… https://t.co/B5Zgkoy4TL</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954301579265</td><td>List(948709436570382336, felixcantillo, null, 259, 6, Perseverancia.)</td><td>List(List(), List())</td><td>es</td><td>@zonacero Jummm. Me huele a humo</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954288984064</td><td>List(893053271245549568, mangootaktk, null, 2086, 131, null)</td><td>List(List(), List())</td><td>und</td><td>RT @DatAzzPhatAF: https://t.co/Ccg78SZLNx</td><td>Mon Jan 08 18:47:59 +0000 2018</td><td>null</td><td>null</td><td>false</td></tr><tr><td>950438954297450497</td><td>List(941196347486752769, figendinceralr1, null, 33,

# %%
# TEST - Run this cell to test your solution
cols = tweetWithMaliciousDF.columns
sample = tweetWithMaliciousDF.first()

dbTest("ET2-P-08-08-01", True, "maliciousAcct" in cols and "id" in cols)
dbTest("ET2-P-08-08-02", 950438954272096257, sample["id"])
dbTest("ET2-P-08-08-03", False, sample["maliciousAcct"])

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ## Exercise 4: Load Records
#
# Transform your two DataFrames to 4 partitions and save the results to the following endpoints:
#
# | DataFrame              | Endpoint                            |
# |:-----------------------|:------------------------------------|
# | `urlTrendsDF`          | `userhome + /tmp/urlTrends.parquet`            |
# | `tweetWithMaliciousDF` | `userhome + /tmp/tweetWithMaliciousDF.parquet` |

# %%
urlTrendsDF.repartition(4).write.mode("OVERWRITE").parquet(userhome + "/tmp/urlTrends.parquet")
tweetWithMaliciousDF.repartition(4).write.mode("OVERWRITE").parquet(userhome + "/tmp/tweetWithMaliciousDF.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution
urlTrendsDFTemp = spark.read.parquet(userhome + "/tmp/urlTrends.parquet")
tweetWithMaliciousDFTemp = spark.read.parquet(userhome + "/tmp/tweetWithMaliciousDF.parquet")

dbTest("ET2-P-08-09-01", 4, urlTrendsDFTemp.rdd.getNumPartitions())
dbTest("ET2-P-08-09-02", 4, tweetWithMaliciousDFTemp.rdd.getNumPartitions())

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ## IMPORTANT Next Steps
# * Please complete the <a href="https://www.surveymonkey.com/r/VYGM9TD" target="_blank">short feedback survey</a>.  Your input is extremely important and shapes future course development.
# * Congratulations, you have completed ETL Part 2!

# %% [markdown]
# -sandbox
# &copy; 2019 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
