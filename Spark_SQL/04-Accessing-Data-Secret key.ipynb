# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # Accessing Data
#
# Apache Spark&trade; and Databricks&reg; have numerous ways to access your data.
#
# ## In this lesson you
# * Create a table from an existing file
# * Create a table by uploading a data file from your local machine
# * Mount an S3 bucket to DBFS
# * Create tables for Databricks data sets to use throughout the course
#
# ## Audience
# * Primary Audience: Data Analysts
# * Additional Audiences: Data Engineers and Data Scientists
#
# ## Prerequisites
# * Web browser: Chrome or Firefox
# * Lesson: <a href="$./01-Getting-Started">Getting Started</a>
# * Concept: <a href="https://www.w3schools.com/sql/" target="_blank">Basic SQL</a>

# %% [markdown]
# ### Getting Started
#
# Run the following cell to configure our "classroom."

# %%
# %run "./Includes/Classroom-Setup"

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/nf81as9ya0?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/nf81as9ya0?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# ### Create a table from an existing file
#
# DBFS (the <a href="https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html" target="_blank">Databricks File System</a>) is the built-in, S3-backed, alternative to
# HDFS (the <a href="http://hadoop.apache.org/docs/current/hadoop-project-dist/hadoop-hdfs/HdfsUserGuide.html" target="_blank">Hadoop Distributed File System</a>).
#
# Creating a table from an existing file in DBFS allows you to access the file as if it were a Spark table. It does **not** copy any data.

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/ysgdonjuk6?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/ysgdonjuk6?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# -sandbox
# The example below creates a table from the **ip-geocode.parquet** file (if it doesn't exist).
#
# For Parquet files, you need to specify only one option: the path to the file.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> A Parquet "file" is actually a collection of files stored in a single directory.  The Parquet format offers features making it the ideal choice for storing "big data" on distributed file systems. For more information, see <a href="https://parquet.apache.org/" target="_blank">Apache Parquet</a>.
#
# You can create a table from an existing DBFS file with a simple SQL `CREATE TABLE` statement. If you don't select a database, the database called "default" is used. Here, we'll use a database called "junk", to remind us to delete these tables later.

# %%
# %sql
CREATE DATABASE IF NOT EXISTS junk;

USE junk;

CREATE TABLE IF NOT EXISTS IPGeocode
  USING parquet
  OPTIONS (
    path "dbfs:/mnt/training/ip-geocode.parquet"
  )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# -sandbox
# Now the table has been defined. You can see it in Databricks.
# 0. Click the **Data** icon on the left sidebar<br/>
# <div><img src="https://files.training.databricks.com/images/eLearning/data-tab.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px"/></div>
# 0. Select the database **junk**.
# 0. Select the table **ipgeocode**.
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> Right-click and open in a new tab, so you don't lose your place in this notebook
# <div><img src="https://files.training.databricks.com/images/eLearning/database.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px"/></div>

# %% [markdown]
# -sandbox
# You see the schema of the table, along with a sample of its data.
#
# <img src="https://files.training.databricks.com/images/eLearning/db-table-example-1.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px"/>

# %% [markdown]
# ### File formats other than Parquet
#
# You can also create a table from other file formats.
#
# One common format is CSV (comma-separated-values) for which you can specify:
# * The file's delimiter, the default is "**,**"
# * Whether the file has a header or not, the default is **false**
# * Whether or not to infer the schema, the default is **false**

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/brunhjed4t?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/brunhjed4t?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# In order to know which options to use, look at the first couple of lines of the file.
#
# Take a look at the head of the file **/mnt/training/bikeSharing/data-001/day.csv.**

# %%
# %fs head /mnt/training/bikeSharing/data-001/day.csv --maxBytes=492
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 492 bytes]
# instant,dteday,season,yr,mnth,holiday,weekday,workingday,weathersit,temp,atemp,hum,windspeed,casual,registered,cnt
# 1,2011-01-01,1,0,1,0,6,0,2,0.344167,0.363625,0.805833,0.160446,331,654,985
# 2,2011-01-02,1,0,1,0,0,0,2,0.363478,0.353739,0.696087,0.248539,131,670,801
# 3,2011-01-03,1,0,1,0,1,1,1,0.196364,0.189405,0.437273,0.248309,120,1229,1349
# 4,2011-01-04,1,0,1,0,2,1,1,0.2,0.212122,0.590435,0.160296,108,1454,1562
# 5,2011-01-05,1,0,1,0,3,1,1,0.226957,0.22927,0.436957,0.1869,82,1518,1600
# </div>

# %% [markdown]
# Spark can create a table from that CSV file, as well.
#
# As you can see above:
# * There is a header
# * The file is comma separated (the default)
# * Let Spark infer what the schema is

# %%
# %sql
CREATE TABLE IF NOT EXISTS BikeSharingDay
  USING csv
  OPTIONS (
    path "/mnt/training/bikeSharing/data-001/day.csv",
    inferSchema "true",
    header "true"
  )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Now the table is defined, view its contents with a simple select statement.

# %%
# %sql
SELECT * FROM BikeSharingDay
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>instant</th><th>dteday</th><th>season</th><th>yr</th><th>mnth</th><th>holiday</th><th>weekday</th><th>workingday</th><th>weathersit</th><th>temp</th><th>atemp</th><th>hum</th><th>windspeed</th><th>casual</th><th>registered</th><th>cnt</th></tr></thead><tbody><tr><td>1</td><td>2011-01-01T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>6</td><td>0</td><td>2</td><td>0.344167</td><td>0.363625</td><td>0.805833</td><td>0.160446</td><td>331</td><td>654</td><td>985</td></tr><tr><td>2</td><td>2011-01-02T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>2</td><td>0.363478</td><td>0.353739</td><td>0.696087</td><td>0.248539</td><td>131</td><td>670</td><td>801</td></tr><tr><td>3</td><td>2011-01-03T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>1</td><td>1</td><td>0.196364</td><td>0.189405</td><td>0.437273</td><td>0.248309</td><td>120</td><td>1229</td><td>1349</td></tr><tr><td>4</td><td>2011-01-04T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>2</td><td>1</td><td>1</td><td>0.2</td><td>0.212122</td><td>0.590435</td><td>0.160296</td><td>108</td><td>1454</td><td>1562</td></tr><tr><td>5</td><td>2011-01-05T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>3</td><td>1</td><td>1</td><td>0.226957</td><td>0.22927</td><td>0.436957</td><td>0.1869</td><td>82</td><td>1518</td><td>1600</td></tr><tr><td>6</td><td>2011-01-06T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>4</td><td>1</td><td>1</td><td>0.204348</td><td>0.233209</td><td>0.518261</td><td>0.0895652</td><td>88</td><td>1518</td><td>1606</td></tr><tr><td>7</td><td>2011-01-07T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>5</td><td>1</td><td>2</td><td>0.196522</td><td>0.208839</td><td>0.498696</td><td>0.168726</td><td>148</td><td>1362</td><td>1510</td></tr><tr><td>8</td><td>2011-01-08T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>6</td><td>0</td><td>2</td><td>0.165</td><td>0.162254</td><td>0.535833</td><td>0.266804</td><td>68</td><td>891</td><td>959</td></tr><tr><td>9</td><td>2011-01-09T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0.138333</td><td>0.116175</td><td>0.434167</td><td>0.36195</td><td>54</td><td>768</td><td>822</td></tr><tr><td>10</td><td>2011-01-10T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>1</td><td>1</td><td>0.150833</td><td>0.150888</td><td>0.482917</td><td>0.223267</td><td>41</td><td>1280</td><td>1321</td></tr><tr><td>11</td><td>2011-01-11T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>2</td><td>1</td><td>2</td><td>0.169091</td><td>0.191464</td><td>0.686364</td><td>0.122132</td><td>43</td><td>1220</td><td>1263</td></tr><tr><td>12</td><td>2011-01-12T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>3</td><td>1</td><td>1</td><td>0.172727</td><td>0.160473</td><td>0.599545</td><td>0.304627</td><td>25</td><td>1137</td><td>1162</td></tr><tr><td>13</td><td>2011-01-13T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>4</td><td>1</td><td>1</td><td>0.165</td><td>0.150883</td><td>0.470417</td><td>0.301</td><td>38</td><td>1368</td><td>1406</td></tr><tr><td>14</td><td>2011-01-14T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>5</td><td>1</td><td>1</td><td>0.16087</td><td>0.188413</td><td>0.537826</td><td>0.126548</td><td>54</td><td>1367</td><td>1421</td></tr><tr><td>15</td><td>2011-01-15T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>6</td><td>0</td><td>2</td><td>0.233333</td><td>0.248112</td><td>0.49875</td><td>0.157963</td><td>222</td><td>1026</td><td>1248</td></tr><tr><td>16</td><td>2011-01-16T00:00:00.000+0000</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0.231667</td><td>0.234217</td><td>0.48375</td> ...

# %% [markdown]
# -sandbox
# Next, drop the table.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> This does not delete the file from which the table was created.  Rather, it simply removes the table definition from Spark.

# %%
# %sql
DROP TABLE BikeSharingDay
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Upload a local file as a table
#
# The last two examples use files already loaded on the "server."
#
# Databricks also supports creating tables by uploading files.
#
# Next, download the following file to your local machine: <a href="https://s3-us-west-2.amazonaws.com/databricks-corp-training/common/dataframes/state-income.csv">state-income.csv</a>

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/anplj4runo?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/anplj4runo?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# -sandbox
# Select **Data** from the sidebar, and click on the **junk** database.
#
# This time, select the **+** icon to create a new table.
#
# <img src="https://files.training.databricks.com/images/eLearning/create-table-1-junk-db.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px"/>
#
# Ensure that **Upload File** is selected. Then, select the **state-income.csv** file from your machine, or drag-and-drop the file to initiate the upload.
#
# <img src="https://files.training.databricks.com/images/eLearning/create-table-2.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px"/>

# %% [markdown]
# -sandbox
# Once the file is uploaded, create the actual table:
#
# 1. Click the **Create Table with UI** button
# <img src="https://files.training.databricks.com/images/eLearning/create-table-3.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; margin: 20px"/>
# 2. In the drop-down dialog, select a cluster
# 3. Click the **Preview Table** button
# <img src="https://files.training.databricks.com/images/eLearning/create-table-4.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; margin: 20px"/>
# 4. Another dialog will drop down. Choose the **junk** database
# 5. Select the **First row is header** checkbox
# 6. Click the **Create Table** button
#
# <img src="https://files.training.databricks.com/images/eLearning/create-table-5.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; margin-top: 20px"/>

# %% [markdown]
# -sandbox
# Once Databricks finishes processing the file, you'll see another table preview.
#
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> Databricks tries to choose a table name that doesn't clash with tables created by other users. However, a name clash is still possible. If the table already exists, you'll see an error like the following:
#
# <img src="https://files.training.databricks.com/images/eLearning/create-table-6.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; margin-top: 20px; padding: 10px"/>
#
# If that happens, just type in a different table name, and try again.

# %% [markdown]
# Next, drop the table to ensure other users don't have a name conflict when uploading their tables.

# %%
# %sql
DROP TABLE IF EXISTS state_income
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### How to mount an S3 bucket to DBFS
#
# Amazon Web Services (AWS) provides cloud file storage in the form of the Amazon Simple Storage Service (S3).  Files are stored in "buckets."
# If you have an S3 account, you can create a bucket, store data files in that bucket, and mount the bucket as a DBFS directory.
#
# Once the bucket is mounted as a DBFS directory, you can access it without exposing your S3 keys.

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/yfd41f8du5?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/yfd41f8du5?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# Take a look at the buckets already mounted to your DBFS:

# %%
# %fs mounts
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mountPoint</th><th>source</th><th>encryptionType</th></tr></thead><tbody><tr><td>/mnt/training</td><td>s3a://databricks-corp-training/common</td><td></td></tr><tr><td>/</td><td>DatabricksRoot</td><td>sse-s3</td></tr><tr><td>/databricks-datasets</td><td>databricks-datasets</td><td>sse-s3</td></tr><tr><td>/databricks-results</td><td>databricks-results</td><td>sse-s3</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# Mount your own bucket to a new mount point. To do so, use the `dbutils.fs.mount(..)` function.
#
# Below, mount a Databricks S3 bucket (using a read-only access and secret key pair), access one of the files in the bucket as a DBFS path, then unmount the bucket.
#
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> The mount point **must** start with `/mnt/`.

# %% [markdown]
# -sandbox
# Create the mount point with `%fs mount`.
#
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> If the directory was already mounted, you would receive the following error:
#
# > Directory already mounted: /mnt/temp-training
#
# In this case, use a different mount point such as `temp-training-2`, and ensure you update all three references below.

# %%
# %fs mount s3a://AKIAJBRYNXGHORDHZB4A:a0BzE1bSegfydr3%2FGE3LSPM6uIV5A4hOUfpH8aFF@databricks-corp-training/common /mnt/temp-training
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res5: Boolean = true
# </div>

# %% [markdown]
# List the contents of the directory you just mounted:

# %%
# %fs ls /mnt/temp-training
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/temp-training/301/</td><td>301/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/Chicago-Crimes-2018.csv</td><td>Chicago-Crimes-2018.csv</td><td>5201668</td></tr><tr><td>dbfs:/mnt/temp-training/City-Data.parquet/</td><td>City-Data.parquet/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/EDGAR-Log-20170329/</td><td>EDGAR-Log-20170329/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/StatLib/</td><td>StatLib/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/UbiqLog4UCI/</td><td>UbiqLog4UCI/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/_META/</td><td>_META/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/adventure-works/</td><td>adventure-works/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/airbnb/</td><td>airbnb/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/airbnb-sf-listings.csv</td><td>airbnb-sf-listings.csv</td><td>764121</td></tr><tr><td>dbfs:/mnt/temp-training/asa/</td><td>asa/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/auto-mpg.csv</td><td>auto-mpg.csv</td><td>18045</td></tr><tr><td>dbfs:/mnt/temp-training/bigrams/</td><td>bigrams/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/bikeSharing/</td><td>bikeSharing/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/bostonhousing/</td><td>bostonhousing/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/cancer/</td><td>cancer/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/chest-xray/</td><td>chest-xray/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/countries/</td><td>countries/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/crime-data-2016/</td><td>crime-data-2016/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/data/</td><td>data/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/data-cleansing/</td><td>data-cleansing/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/databricks-blog.json</td><td>databricks-blog.json</td><td>3052424</td></tr><tr><td>dbfs:/mnt/temp-training/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/dataframes/</td><td>dataframes/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/day-of-week/</td><td>day-of-week/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/definitive-guide/</td><td>definitive-guide/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/dl/</td><td>dl/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/enb/</td><td>enb/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/fraud/</td><td>fraud/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/gaming_data/</td><td>gaming_data/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/global-sales/</td><td>global-sales/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/graphx-demo/</td><td>graphx-demo/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/initech/</td><td>initech/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/ip-geocode.parquet/</td><td>ip-geocode.parquet/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/iris/</td><td>iris/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/mini_newsgroups/</td><td>mini_newsgroups/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/mnist/</td><td>mnist/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/movie-reviews/</td><td>movie-reviews/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/movielens/</td><td>movielens/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/movies/</td><td>movies/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/online_retail/</td><td>online_retail/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/philadelphia-crime-data-2015-ytd.csv</td><td>philadelphia-crime-data-2015-ytd.csv</td><td>7469462</td></tr><tr><td>dbfs:/mnt/temp-training/power-plant/</td><td>power-plant/</td><td>0</td></tr><tr><td>dbfs:/mnt/temp-training/purchases.txt</td><td>purchases.txt</td><td>89437</td></tr><tr><td>dbfs:/mnt/temp-training/r ...

# %% [markdown]
# Take a peek at the head of the file `auto-mpg.csv`:

# %%
# %fs head /mnt/temp-training/auto-mpg.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">18,8,307,130,3504,12,70,1,chevrolet chevelle malibu
# 15,8,350,165,3693,11.5,70,1,buick skylark 320
# 18,8,318,150,3436,11,70,1,plymouth satellite
# 16,8,304,150,3433,12,70,1,amc rebel sst
# 17,8,302,140,3449,10.5,70,1,ford torino
# 15,8,429,198,4341,10,70,1,ford galaxie 500
# 14,8,454,220,4354,9,70,1,chevrolet impala
# 14,8,440,215,4312,8.5,70,1,plymouth fury iii
# 14,8,455,225,4425,10,70,1,pontiac catalina
# 15,8,390,190,3850,8.5,70,1,amc ambassador dpl
# 15,8,383,170,3563,10,70,1,dodge challenger se
# 14,8,340,160,3609,8,70,1,plymouth 'cuda 340
# 15,8,400,150,3761,9.5,70,1,chevrolet monte carlo
# 14,8,455,225,3086,10,70,1,buick estate wagon (sw)
# 24,4,113,95,2372,15,70,3,toyota corona mark ii
# 22,6,198,95,2833,15.5,70,1,plymouth duster
# 18,6,199,97,2774,15.5,70,1,amc hornet
# 21,6,200,85,2587,16,70,1,ford maverick
# 27,4,97,88,2130,14.5,70,3,datsun pl510
# 26,4,97,46,1835,20.5,70,2,volkswagen 1131 deluxe sedan
# 25,4,110,87,2672,17.5,70,2,peugeot 504
# 24,4,107,90,2430,14.5,70,2,audi 100 ls
# 25,4,104,95,2375,17.5,70,2,saab 99e
# 26,4,121,113,2234,12.5,70,2,bmw 2002
# 21,6,199,90,2648,15,70,1,amc gremlin
# 10,8,360,215,4615,14,70,1,ford f250
# 10,8,307,200,4376,15,70,1,chevy c20
# 11,8,318,210,4382,13.5,70,1,dodge d200
# 9,8,304,193,4732,18.5,70,1,hi 1200d
# 27,4,97,88,2130,14.5,71,3,datsun pl510
# 28,4,140,90,2264,15.5,71,1,chevrolet vega 2300
# 25,4,113,95,2228,14,71,3,toyota corona
# 25,4,98,?,2046,19,71,1,ford pinto
# 19,6,232,100,2634,13,71,1,amc gremlin
# 16,6,225,105,3439,15.5,71,1,plymouth satellite custom
# 17,6,250,100,3329,15.5,71,1,chevrolet chevelle malibu
# 19,6,250,88,3302,15.5,71,1,ford torino 500
# 18,6,232,100,3288,15.5,71,1,amc matador
# 14,8,350,165,4209,12,71,1,chevrolet impala
# 14,8,400,175,4464,11.5,71,1,pontiac catalina brougham
# 14,8,351,153,4154,13.5,71,1,ford galaxie 500
# 14,8,318,150,4096,13,71,1,plymouth fury iii
# 12,8,383,180,4955,11.5,71,1,dodge monaco (sw)
# 13,8,400,170,4746,12,71,1,ford country squire (sw)
# 13,8,400,175,5140,12,71,1,pontiac safari (sw)
# 18,6,258,110,2962,13.5,71,1,amc hornet sportabout (sw)
# 22,4,140,72,2408,19,71,1,chevrolet vega (sw)
# 19,6,250,100,3282,15,71,1,pontiac firebird
# 18,6,250,88,3139,14.5,71,1,ford mustang
# 23,4,122,86,2220,14,71,1,mercury capri 2000
# 28,4,116,90,2123,14,71,2,opel 1900
# 30,4,79,70,2074,19.5,71,2,peugeot 304
# 30,4,88,76,2065,14.5,71,2,fiat 124b
# 31,4,71,65,1773,19,71,3,toyota corolla 1200
# 35,4,72,69,1613,18,71,3,datsun 1200
# 27,4,97,60,1834,19,71,2,volkswagen model 111
# 26,4,91,70,1955,20.5,71,1,plymouth cricket
# 24,4,113,95,2278,15.5,72,3,toyota corona hardtop
# 25,4,97.5,80,2126,17,72,1,dodge colt hardtop
# 23,4,97,54,2254,23.5,72,2,volkswagen type 3
# 20,4,140,90,2408,19.5,72,1,chevrolet vega
# 21,4,122,86,2226,16.5,72,1,ford pinto runabout
# 13,8,350,165,4274,12,72,1,chevrolet impala
# 14,8,400,175,4385,12,72,1,pontiac catalina
# 15,8,318,150,4135,13.5,72,1,plymouth fury iii
# 14,8,351,153,4129,13,72,1,ford galaxie 500
# 17,8,304,150,3672,11.5,72,1,amc ambassador sst
# 11,8,429,208,4633,11,72,1,mercury marquis
# 13,8,350,155,4502,13.5,72,1,buick lesabre custom
# 12,8,350,160,4456,13.5,72,1,oldsmobile delta 88 royale
# 13,8,400,190,4422,12.5,72,1,chrysler newport royal
# 19,3,70,97,2330,13.5,72,3,mazda rx2 coupe
# 15,8,304,150,3892,12.5,72,1,amc matador (sw)
# 13,8,307,130,4098,14,72,1,chevrolet chevelle concours (sw)
# 13,8,302,140,4294,16,72,1,ford gran torino (sw)
# 14,8,318,150,4077,14,72,1,plymouth satellite custom (sw)
# 18,4,121,112,2933,14.5,72,2,volvo 145e (sw)
# 22,4,121,76,2511,18,72,2,volkswagen 411 (sw)
# 21,4,120,87,2979,19.5,72,2,peugeot 504 (sw)
# 26,4,96,69,2189,18,72,2,renault 12 (sw)
# 22,4,122,86,2395,16,72,1,ford pinto (sw)
# 28,4,97,92,2288,17,72,3,datsun 510 (sw)
# 23,4,120,97,2506,14.5,72,3,toyouta corona mark ii (sw)
# 28,4,98,80,2164,15,72,1,dodge colt (sw)
# 27,4,97,88,2100,16.5,72,3,toyota corolla 1600 (sw)
# 13,8,350,175,4100,13,73,1,buick century 350
# 14,8,304,150,3672,11.5,73,1,amc matador
# 13,8,350,145,3988,13,73,1,chevrolet malibu
# 14,8,302,137,4042,14.5,73,1,ford gran torino
# 15,8,318,150,3777,12.5,73,1,dodge coronet custom
# 12,8,429,198,4952,11.5,73,1,mercury marquis brougham
# 13,8,400,150,4464,12,73,1,chevrolet caprice classic
# 13,8,351,158,4363,13,73,1,ford ltd
# 14,8,318,150,4237,14.5,73,1,plymouth fury gran sedan
# 13,8,440,215,4735,11,73,1,chrysler new yorker brougham
# 12,8,455,225,4951,11,73,1,buick electra 225 custom
# 13,8,360,175,3821,11,73,1,amc ambassador brougham
# 18,6,225,105,3121,16.5,73,1,plymouth valiant
# 16,6,250,100,3278,18,73,1,chevrolet nova custom
# 18,6,232,100,2945,16,73,1,amc hornet
# 18,6,250,88,3021,16.5,73,1,ford maverick
# 23,6,198,95,2904,16,73,1,plymouth duster
# 26,4,97,46,1950,21,73,2,volkswagen super beetle
# 11,8,400,150,4997,14,73,1,chevrolet impala
# 12,8,400,167,4906,12.5,73,1,ford country
# 13,8,360,170,4654,13,73,1,plymouth custom suburb
# 12,8,350,180,4499,12.5,73,1,oldsmobile vista cruiser
# 18,6,232,100,2789,15,73,1,amc gremlin
# 20,4,97,88,2279,19,73,3,toyota carina
# 21,4,140,72,2401,19.5,73,1,chevrolet vega
# 22,4,108,94,2379,16.5,73,3,datsun 610
# 18,3,70,90,2124,13.5,73,3,maxda rx3
# 19,4,122,85,2310,18.5,73,1,ford pinto
# 21,6,155,107,2472,14,73,1,mercury capri v6
# 26,4,98,90,2265,15.5,73,2,fiat 124 sport coupe
# 15,8,350,145,4082,13,73,1,chevrolet monte carlo s
# 16,8,400,230,4278,9.5,73,1,pontiac grand prix
# 29,4,68,49,1867,19.5,73,2,fiat 128
# 24,4,116,75,2158,15.5,73,2,opel manta
# 20,4,114,91,2582,14,73,2,audi 100ls
# 19,4,121,112,2868,15.5,73,2,volvo 144ea
# 15,8,318,150,3399,11,73,1,dodge dart custom
# 24,4,121,110,2660,14,73,2,saab 99le
# 20,6,156,122,2807,13.5,73,3,toyota mark ii
# 11,8,350,180,3664,11,73,1,oldsmobile omega
# 20,6,198,95,3102,16.5,74,1,plymouth duster
# 21,6,200,?,2875,17,74,1,ford maverick
# 19,6,232,100,2901,16,74,1,amc hornet
# 15,6,250,100,3336,17,74,1,chevrolet nova
# 31,4,79,67,1950,19,74,3,datsun b210
# 26,4,122,80,2451,16.5,74,1,ford pinto
# 32,4,71,65,1836,21,74,3,toyota corolla 1200
# 25,4,140,75,2542,17,74,1,chevrolet vega
# 16,6,250,100,3781,17,74,1,chevrolet chevelle malibu classic
# 16,6,258,110,3632,18,74,1,amc matador
# 18,6,225,105,3613,16.5,74,1,plymouth satellite sebring
# 16,8,302,140,4141,14,74,1,ford gran torino
# 13,8,350,150,4699,14.5,74,1,buick century luxus (sw)
# 14,8,318,150,4457,13.5,74,1,dodge coronet custom (sw)
# 14,8,302,140,4638,16,74,1,ford gran torino (sw)
# 14,8,304,150,4257,15.5,74,1,amc matador (sw)
# 29,4,98,83,2219,16.5,74,2,audi fox
# 26,4,79,67,1963,15.5,74,2,volkswagen dasher
# 26,4,97,78,2300,14.5,74,2,opel manta
# 31,4,76,52,1649,16.5,74,3,toyota corona
# 32,4,83,61,2003,19,74,3,datsun 710
# 28,4,90,75,2125,14.5,74,1,dodge colt
# 24,4,90,75,2108,15.5,74,2,fiat 128
# 26,4,116,75,2246,14,74,2,fiat 124 tc
# 24,4,120,97,2489,15,74,3,honda civic
# 26,4,108,93,2391,15.5,74,3,subaru
# 31,4,79,67,2000,16,74,2,fiat x1.9
# 19,6,225,95,3264,16,75,1,plymouth valiant custom
# 18,6,250,105,3459,16,75,1,chevrolet nova
# 15,6,250,72,3432,21,75,1,mercury monarch
# 15,6,250,72,3158,19.5,75,1,ford maverick
# 16,8,400,170,4668,11.5,75,1,pontiac catalina
# 15,8,350,145,4440,14,75,1,chevrolet bel air
# 16,8,318,150,4498,14.5,75,1,plymouth grand fury
# 14,8,351,148,4657,13.5,75,1,ford ltd
# 17,6,231,110,3907,21,75,1,buick century
# 16,6,250,105,3897,18.5,75,1,chevroelt chevelle malibu
# 15,6,258,110,3730,19,75,1,amc matador
# 18,6,225,95,3785,19,75,1,plymouth fury
# 21,6,231,110,3039,15,75,1,buick skyhawk
# 20,8,262,110,3221,13.5,75,1,chevrolet monza 2+2
# 13,8,302,129,3169,12,75,1,ford mustang ii
# 29,4,97,75,2171,16,75,3,toyota corolla
# 23,4,140,83,2639,17,75,1,ford pinto
# 20,6,232,100,2914,16,75,1,amc gremlin
# 23,4,140,78,2592,18.5,75,1,pontiac astro
# 24,4,134,96,2702,13.5,75,3,toyota corona
# 25,4,90,71,2223,16.5,75,2,volkswagen dasher
# 24,4,119,97,2545,17,75,3,datsun 710
# 18,6,171,97,2984,14.5,75,1,ford pinto
# 29,4,90,70,1937,14,75,2,volkswagen rabbit
# 19,6,232,90,3211,17,75,1,amc pacer
# 23,4,115,95,2694,15,75,2,

# %% [markdown]
# Now you are done, unmount the directory.

# %%
# %fs unmount /mnt/temp-training
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/temp-training has been unmounted.
# res8: Boolean = true
# </div>

# %% [markdown]
# ## Summary
#
# Databricks allows you to:
#   * Create tables from existing data
#   * Create tables from uploaded files
#   * Mount your own S3 buckets

# %% [markdown]
# ## Review Questions
# **Q:** How can you see which tables have been created?
# **A:** Go to the **Data** section using the button-bar to the left.
#
# **Q:** What is Amazon S3?
# **A:** Amazon S3 stands for Simple Storage Service.  It provides cloud-optimized storage of large data files that easily scales with your storage needs.
#
# **Q:** What is DBFS?
# **A:** DBFS stands for Databricks File System.  DBFS provides for the cloud what the Hadoop File System (HDFS) provides for local spark deployments.  DBFS uses Amazon S3 and makes it easy to access files by name.
#
# **Q:** Which is more efficient to query, a parquet file or a CSV file?
# **A:** Parquet files are highly optimized binary formats for storing tables.  The overhead is less than required to parse a CSV file.  Parquet is the big data analogue to CSV as it is optimized, distributed, and more fault tolerant than CSV files.
#
# **Q:** How can you create a new table?
# **A:** Create new tables by either:
# * Uploading a new file using the Data tab on the left.
# * Mounting an existing file from DBFS.
#
# **Q:** What is the SQL syntax for defining a table in Spark from an existing parquet file in DBFS?
# **A:** ```CREATE TABLE IF NOT EXISTS IPGeocode
# USING parquet
# OPTIONS (
#   path "dbfs:/mnt/training/ip-geocode.parquet"
# )```

# %% [markdown]
# ## Next Steps
#
# Start the next lesson, [Querying JSON & Hierarchical Data with SQL]($./05-Querying-JSON).

# %% [markdown]
# ## Additional Topics & Resources
#
# * <a href="https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html" target="_blank">The Databricks DBFS File System</a>

# %% [markdown]
# -sandbox
# &copy; 2019 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
